# %% [markdown]
# **Import Data**

# %%
import pandas as pd
df=pd.read_csv('/content/Online Retail.csv')
df
# Out:
#        index InvoiceNo StockCode                          Description  \
# 0          0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1          1    536365     71053                  WHITE METAL LANTERN
# 2          2    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3          3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4          4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# ...      ...       ...       ...                                  ...
# 11704  11704    537262     48111                DOORMAT 3 SMILEY CATS
# 11705  11705    537262     21955    DOORMAT UNION JACK GUNS AND ROSES
# 11706  11706    537262     48138                   DOORMAT UNION FLAG
# 11707  11707    537262     22365            DOORMAT RESPECTABLE HOUSE
# 11708  11708    537262     48188              DOORMAT WELCOME PUPPIES
#
#        Quantity      InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# Explore Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11709 entries, 0 to 11708
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        11709 non-null  int64
#  1   InvoiceNo    11709 non-null  object
#  2   StockCode    11709 non-null  object
#  3   Description  11667 non-null  object
#  4   Quantity     11709 non-null  int64
#  5   InvoiceDate  11709 non-null  object
#  6   UnitPrice    11708 non-null  float64
#  7   CustomerID   8206 non-null   float64
#  8   Country      11708 non-null  object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 823.4+ KB

# %%
# type issues (  InvoiceNo - StockCode  )

# %%
df.head(10)
# Out:
#    index InvoiceNo StockCode                          Description  Quantity  \
# 0      0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      1    536365     71053                  WHITE METAL LANTERN         6
# 2      2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3      3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5      5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6      6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7      7    536366     22633               HAND WARMER UNION JACK         6
# 8      8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9      9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# ...

# %%
df.tail(10)
# Out:
#        index InvoiceNo StockCode                        Description  Quantity  \
# 11699  11699    537262     21930           JUMBO STORAGE BAG SKULLS         1
# 11700  11700    537262     22382         LUNCH BAG SPACEBOY DESIGN          1
# 11701  11701    537262     71477  COLOUR GLASS. STAR T-LIGHT HOLDER         1
# 11702  11702    537262    15056N          EDWARDIAN PARASOL NATURAL         3
# 11703  11703    537262     20685              DOORMAT RED RETROSPOT         1
# 11704  11704    537262     48111              DOORMAT 3 SMILEY CATS         1
# 11705  11705    537262     21955  DOORMAT UNION JACK GUNS AND ROSES         1
# 11706  11706    537262     48138                 DOORMAT UNION FLAG         2
# 11707  11707    537262     22365          DOORMAT RESPECTABLE HOUSE         1
# 11708  11708    537262     48188            DOORMAT WELCOME PUPPIES         1
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.shape
# Out:
# (11709, 9)

# %%
df.describe()
# Out:
#               index      Quantity     UnitPrice    CustomerID
# count  11709.000000  11709.000000  11708.000000   8206.000000
# mean    5854.000000      7.532326      4.042778  15570.112479
# std     3380.241485     96.794719     17.775830   1763.167561
# min        0.000000  -9360.000000      0.000000  12395.000000
# 25%     2927.000000      1.000000      1.250000  14237.000000
# 50%     5854.000000      2.000000      2.510000  15574.000000
# 75%     8781.000000      6.000000      4.240000  17198.000000
# max    11708.000000   2880.000000    940.870000  18239.000000

# %%
df.dtypes
# Out:
# index            int64
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
df.columns
# Out:
# Index(['index', 'InvoiceNo', 'StockCode', 'Description', 'Quantity',
#        'InvoiceDate', 'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %% [markdown]
# **check duplicates**

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(columns='index',inplace=True)

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 211

# %% [markdown]
# **Handling duplicates**

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **check nulls**

# %%
df.isnull().sum()
(df.isnull().sum()/df.shape[0])*100
# Out:
# InvoiceNo       0.000000
# StockCode       0.000000
# Description     0.365281
# Quantity        0.000000
# InvoiceDate     0.000000
# UnitPrice       0.008697
# CustomerID     30.466168
# Country         0.008697
# dtype: float64

# %%
# nulls issues ( Description - CustomerID - UnitPrice)

# %% [markdown]
# **check irrelevant**

# %%
df['Country'].value_counts()
# Out:
# Country
# United Kingdom    10878
# Germany             195
# EIRE                109
# France              106
# Norway               73
# Lithuania            34
# Italy                25
# Japan                16
# Australia            14
# Portugal             14
# Belgium              12
# Poland                8
# Switzerland           6
# Spain                 5
# Netherlands           2
# Name: count, dtype: int64

# %% [markdown]
# **handling datatypes**

# %%
df['InvoiceNo']=pd.to_numeric(df['InvoiceNo'],errors='coerce')
df['StockCode']=pd.to_numeric(df['StockCode'],errors='coerce')

# %%
df.dtypes
# Out:
# InvoiceNo      float64
# StockCode      float64
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %% [markdown]
# **check normal distibution of the null issues columns**

# %%
print(df['CustomerID'].mean())
print(df['CustomerID'].median())
# Out:
# 15561.664540337712
# 15574.0

# %%
import seaborn as sns
sns.histplot(df['CustomerID'],kde=True);

# %%
df['Description']=pd.to_numeric(df['Description'],errors='coerce')
df.dtypes
# Out:
# InvoiceNo      float64
# StockCode      float64
# Description    float64
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
print(df['Description'].mean())
print(df['Description'].median())
# Out:
# nan
# nan

# %%
sns.histplot(df['Description'],kde=True);

# %% [markdown]
# **handling null columns**

# %%
# handle CustomerID column
df['CustomerID']=df['CustomerID'].fillna(df['CustomerID'].median())
df['CustomerID'].isnull().sum()
# Out:
# 0

# %%
# handle Description column
df['Description']=df['Description'].fillna(0)
df['Description'].isnull().sum()
# Out:
# 0

# %%
df.drop(columns='UnitPrice',inplace=True)
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'CustomerID', 'Country'],
#       dtype='object')

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# InvoiceNo       1.061054
# StockCode      12.532614
# Description     0.000000
# Quantity        0.000000
# InvoiceDate     0.000000
# CustomerID      0.000000
# Country         0.008697
# dtype: float64

# %%
# handle null values in (invoice - stockcode)
df['InvoiceNo'].fillna(0,inplace=True)
df['InvoiceNo'].isnull().sum()
# Out:
# <ipython-input-87-722005e384d2>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['InvoiceNo'].fillna(0,inplace=True)
# 0

# %%
print(df['StockCode'].mean())
print(df['StockCode'].median())
# Out:
# 27714.842895495676
# 22382.0

# %%
df['StockCode']=df['StockCode'].fillna(df['StockCode'].median())
df['StockCode'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# CustomerID     0
# Country        1
# dtype: int64

# %%
df.dropna(subset=['Country'],inplace=True)
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# CustomerID     0
# Country        0
# dtype: int64

# %% [markdown]
# **save file**

# %%
df.to_csv('cleaned_data.csv',index=False)
